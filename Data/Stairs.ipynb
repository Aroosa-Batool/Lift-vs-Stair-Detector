# 25           -1.19            9.52  2025-01-01T18:49:53.610Z    0
# 26           -0.63           10.08  2025-01-01T18:49:53.919Z    0
# 27           -0.44           11.07  2025-01-01T18:49:54.235Z    0
# 28            0.23            7.36  2025-01-01T18:49:54.546Z    0
# 29            2.12            6.95  2025-01-01T18:49:54.852Z    0
# 30            0.89            5.61  2025-01-01T18:49:55.149Z    0
# 31           -5.13           13.15  2025-01-01T18:49:55.447Z    0
# 32           -0.14           11.37  2025-01-01T18:49:55.752Z    0
# 33            0.21            8.30  2025-01-01T18:49:56.177Z    0
# 34            0.28           10.66  2025-01-01T18:49:56.483Z    0
# 35            0.28            8.05  2025-01-01T18:49:56.891Z    0
# 36           -0.18            8.46  2025-01-01T18:49:57.190Z    0
# 37           -1.56            8.85  2025-01-01T18:49:57.608Z    0
# 38           -1.56            8.04  2025-01-01T18:49:58.017Z    0
# 39            0.63            9.07  2025-01-01T18:49:58.325Z    0
# 40           -1.35            8.53  2025-01-01T18:49:58.642Z    0
# 41           -0.38            8.84  2025-01-01T18:49:59.045Z    0
# 42            0.60           10.31  2025-01-01T18:49:59.452Z    0
# 43           -0.39            8.02  2025-01-01T18:49:59.883Z    0
# 44           -1.07            7.82  2025-01-01T18:50:00.200Z    0
# 45           -1.36            7.67  2025-01-01T18:50:00.579Z    0
# 46           -0.70            8.01  2025-01-01T18:50:01.089Z    0

# %%
# Combine the datasets
analysis_data = pd.concat([file1,
                           file2],
                          ignore_index=True)

# %%
analysis_data
# Out:
#                             0         1         2               3  \
# 0                         _id  pressure  altitude  acceleration_x
# 1    67758d46730962ef7ab56e28     93507    672.12           -2.55
# 2    67758d47730962ef7ab56e2a  96882.25    376.57            5.35
# 3    67758d47730962ef7ab56e2c  96889.39    375.95            4.02
# 4    67758d47730962ef7ab56e2e  96890.16    375.89            1.06
# ..                        ...       ...       ...             ...
# 96                        NaN       NaN       NaN             NaN
# 97                        NaN       NaN       NaN             NaN
# 98                        NaN       NaN       NaN             NaN
# 99                        NaN       NaN       NaN             NaN
# 100                       NaN       NaN       NaN             NaN
#
#                   4               5                         6    7  \
# 0    acceleration_y  acceleration_z                 timestamp  __v
# 1             -8.17             4.9  2025-01-01T18:45:26.762Z    0
# 2             -1.37            5.89  2025-01-01T18:45:27.175Z    0
# 3             -2.53            6.82  2025-01-01T18:45:27.582Z    0
# 4             -5.91           10.21  2025-01-01T18:45:27.910Z    0
# ..              ...             ...                       ...  ...
# 96              NaN             NaN                       NaN  NaN
# 97              NaN             NaN                       NaN  NaN
# 98              NaN             NaN                       NaN  NaN
# 99              NaN             NaN                       NaN  NaN
# 100             NaN             NaN                       NaN  NaN
#
#                           _id  pressure  altitude  acceleration_x  \
# 0                         NaN       NaN       NaN             NaN
# 1                         NaN       NaN       NaN             NaN
# 2                         NaN       NaN       NaN             NaN
# 3                         NaN       NaN       NaN             NaN
# 4                         NaN       NaN       NaN             NaN
# ..                        ...       ...       ...             ...
# 96   67758e57730962ef7ab56ee6  96898.25    375.19           -2.82
# 27           -0.44           11.07  2025-01-01T18:49:54.235Z    0
# 28            0.23            7.36  2025-01-01T18:49:54.546Z    0
# 29            2.12            6.95  2025-01-01T18:49:54.852Z    0
# 30            0.89            5.61  2025-01-01T18:49:55.149Z    0
# 31           -5.13           13.15  2025-01-01T18:49:55.447Z    0
# 32           -0.14           11.37  2025-01-01T18:49:55.752Z    0
# 33            0.21            8.30  2025-01-01T18:49:56.177Z    0
# 34            0.28           10.66  2025-01-01T18:49:56.483Z    0
# 35            0.28            8.05  2025-01-01T18:49:56.891Z    0
# 36           -0.18            8.46  2025-01-01T18:49:57.190Z    0
# 37           -1.56            8.85  2025-01-01T18:49:57.608Z    0
# 38           -1.56            8.04  2025-01-01T18:49:58.017Z    0
# 39            0.63            9.07  2025-01-01T18:49:58.325Z    0
# 40           -1.35            8.53  2025-01-01T18:49:58.642Z    0
# 41           -0.38            8.84  2025-01-01T18:49:59.045Z    0
# 42            0.60           10.31  2025-01-01T18:49:59.452Z    0
# 43           -0.39            8.02  2025-01-01T18:49:59.883Z    0
# 44           -1.07            7.82  2025-01-01T18:50:00.200Z    0
# 45           -1.36            7.67  2025-01-01T18:50:00.579Z    0
# 46           -0.70            8.01  2025-01-01T18:50:01.089Z    0

# %%
# Check the column names to ensure correct data mapping
print("\nColumn Names:")
print(analysis_data.columns)
# Out:
# Column Names:
# Index([               0,                1,                2,                3,
#                       4,                5,                6,                7,
#                   '_id',       'pressure',       'altitude', 'acceleration_x',
#        'acceleration_y', 'acceleration_z',      'timestamp',            '__v'],
#       dtype='object')

# %%
# Calculate acceleration magnitude
analysis_data['Acceleration_Magnitude'] = (analysis_data['acceleration_x']**2 +
                                           analysis_data['acceleration_y']**2 +
                                           analysis_data['acceleration_z']**2)**0.5

# %%
# Calculate mean and variance
pressure_mean = analysis_data['pressure'].mean()
pressure_variance = analysis_data['pressure'].var()

acceleration_mean = analysis_data['Acceleration_Magnitude'].mean()
acceleration_variance = analysis_data['Acceleration_Magnitude'].var()

# Display results
print(f"Pressure Mean: {pressure_mean:.2f}, Variance: {pressure_variance:.2f}")
print(f"Acceleration Magnitude Mean: {acceleration_mean:.2f}, Variance: {acceleration_variance:.2f}")
# Out:
# Pressure Mean: 96855.92, Variance: 224245.53
# Acceleration Magnitude Mean: 9.56, Variance: 2.34

# %%
print(analysis_data.dtypes)
# Out:
# 0                          object
# 1                          object
# 2                          object
# 3                          object
# 4                          object
# 5                          object
# 6                          object
# 7                          object
# _id                        object
# pressure                  float64
# altitude                  float64
# acceleration_x            float64
# acceleration_y            float64
# acceleration_z            float64
# timestamp                  object
# __v                       float64
# Acceleration_Magnitude    float64
# dtype: object

# %%
# Convert the 'timestamp' column to a datetime object
analysis_data['timestamp'] = pd.to_datetime(analysis_data['timestamp'], errors='coerce')

# Check for any NaT values after conversion
print(analysis_data['timestamp'].isna().sum())
# Out:
# 54

# %%
analysis_data = analysis_data.dropna(subset=['timestamp'])

# %%
import matplotlib.pyplot as plt

# Plot pressure over time
plt.figure(figsize=(10, 5))
plt.plot(analysis_data['timestamp'], analysis_data['pressure'], label='Pressure')
plt.xlabel('Timestamp')
plt.ylabel('Pressure')
plt.title('Pressure Over Time')
plt.legend()
plt.show()

# Plot Acceleration Magnitude over time
plt.figure(figsize=(10, 5))
plt.plot(analysis_data['timestamp'], analysis_data['Acceleration_Magnitude'], label='Acceleration Magnitude', color='orange')
plt.xlabel('Timestamp')
plt.ylabel('Acceleration Magnitude')
plt.title('Acceleration Magnitude Over Time')
plt.legend()
plt.show()

# %%
# Calculate mean and variance for Pressure
pressure_mean = analysis_data['pressure'].mean()
pressure_variance = analysis_data['pressure'].var()

# %%
# Calculate mean and variance for Acceleration Magnitude
acceleration_mean = analysis_data['Acceleration_Magnitude'].mean()
acceleration_variance = analysis_data['Acceleration_Magnitude'].var()

# %%
# Plot the data for visualization
fig, axs = plt.subplots(3, 1, figsize=(12, 12))

# Plot Pressure Data
axs[0].plot(analysis_data['timestamp'], analysis_data['pressure'], label="Pressure (Pa)", color="blue")
axs[0].axhline(y=pressure_mean, color='r', linestyle='--', label=f"Mean: {pressure_mean:.2f} Pa")
axs[0].set_title("Pressure Data Over Time")
axs[0].set_xlabel("Timestamp")
axs[0].set_ylabel("Pressure (Pa)")
axs[0].legend()

# Plot Acceleration Magnitude Data
axs[1].plot(analysis_data['timestamp'], analysis_data['Acceleration_Magnitude'], label="Acceleration Magnitude (m/s^2)", color="green")
axs[1].axhline(y=acceleration_mean, color='r', linestyle='--', label=f"Mean: {acceleration_mean:.2f} m/s^2")
axs[1].set_title("Acceleration Magnitude Over Time")
axs[1].set_xlabel("Timestamp")
axs[1].set_ylabel("Acceleration Magnitude (m/s^2)")
axs[1].legend()


# Show the plots
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Plot pressure data with mean
plt.figure(figsize=(10, 6))
plt.plot(analysis_data['timestamp'], analysis_data['pressure'], label='Pressure (Pa)', color='blue')
plt.axhline(y=pressure_mean, color='red', linestyle='--', label=f'Mean: {pressure_mean:.2f}')
plt.fill_between(
    analysis_data['timestamp'],
    pressure_mean - np.sqrt(pressure_variance),
    pressure_mean + np.sqrt(pressure_variance),
    color='red', alpha=0.2, label='1 Std Dev (Approx.)'
)
plt.title('Pressure with Mean and Variance')
plt.xlabel('Timestamp')
plt.ylabel('Pressure (Pa)')
plt.legend()
plt.show()

# %%
# Pressure histogram
plt.figure(figsize=(10, 6))
plt.hist(analysis_data['pressure'], bins=30, color='blue', alpha=0.7, label='Pressure')
plt.axvline(pressure_mean, color='red', linestyle='--', label=f'Mean: {pressure_mean:.2f}')
plt.axvline(pressure_mean + np.sqrt(pressure_variance), color='green', linestyle='--', label='1 Std Dev (Upper)')
plt.axvline(pressure_mean - np.sqrt(pressure_variance), color='green', linestyle='--', label='1 Std Dev (Lower)')
plt.title('Pressure Distribution')
plt.xlabel('Pressure (Pa)')
plt.ylabel('Frequency')
plt.legend()
plt.show()

# %%
pressure_variance
# Out:
# 224245.52562581

# %%
import pandas as pd

# Define chunk size
chunk_size = 3

# Initialize lists to store computed values
means_pressure = []
means_acceleration = []
variances_pressure = []
variances_acc_x = []
variances_acc_y = []
variances_acc_z = []

# Iterate through the dataset in chunks
for i in range(0, len(analysis_data), chunk_size):
    chunk = analysis_data.iloc[i:i+chunk_size]  # Select 3 rows at a time

    # Compute mean pressure
    mean_pressure = chunk['pressure'].mean()
    means_pressure.append(mean_pressure)

    # Compute mean acceleration magnitude
    mean_acceleration = chunk[['acceleration_x', 'acceleration_y', 'acceleration_z']].mean().mean()
    means_acceleration.append(mean_acceleration)

    # Compute variance of pressure
    variance_pressure = chunk['pressure'].var()
    variances_pressure.append(variance_pressure)

    # Compute variance of each acceleration axis
    variance_acc_x = chunk['acceleration_x'].var()
    variance_acc_y = chunk['acceleration_y'].var()
    variance_acc_z = chunk['acceleration_z'].var()

    variances_acc_x.append(variance_acc_x)
    variances_acc_y.append(variance_acc_y)
    variances_acc_z.append(variance_acc_z)

# Create a DataFrame to store results
summary_df = pd.DataFrame({
    'Mean_Pressure': means_pressure,
    'Mean_Acceleration': means_acceleration,
    'Variance_Pressure': variances_pressure,
    'Variance_Acceleration_X': variances_acc_x,
    'Variance_Acceleration_Y': variances_acc_y,
    'Variance_Acceleration_Z': variances_acc_z
})

# Display all rows without truncation
pd.set_option('display.max_rows', None)

# Print the DataFrame
print(summary_df)

# Reset to default after displaying if needed
pd.reset_option('display.max_rows')
# Out:
#     Mean_Pressure  Mean_Acceleration  Variance_Pressure  \
# 0    95864.380000           3.226667       3.573350e+06
# 1    96948.640000           3.518889       5.229480e+01
# 2    96959.566667           2.850000       2.288633e+02
# 3    96942.703333           3.587778       6.206763e+01
# 4    96931.250000           3.200000       1.135960e+01
# 5    96933.546667           3.853333       2.992373e+01
# 6    96942.546667           3.676667       6.588946e+02
# 7    96920.623333           3.215556       1.214489e+02
# 8    96917.130000           3.283333       1.112070e+01
# 9    96924.743333           3.032222       7.113633e+00
# 10   96915.040000           3.127778       2.304310e+01
# 11   96907.550000           3.387778       3.159490e+01
# 12   96905.283333           2.376667       1.172633e+00
# 13   96898.503333           2.486667       1.814233e+00
# 14   96899.106667           1.698889       4.773433e+00
# 15   96898.250000           0.856667       1.185800e+00
#
#     Variance_Acceleration_X  Variance_Acceleration_Y  Variance_Acceleration_Z
# 0                  1.309233                 1.945233                 0.014433
# 1                  0.999433                 0.097233                 2.135033
# 2                  1.269100                 0.350633                 0.411233
# 3                  0.384133                 0.560833                 1.464700
# 4                  0.073233                 0.176433                 0.537033
# 5                  0.006300                 0.174633                 0.171033
# 6                  0.190233                 0.133433                 0.864133
# 7                  1.917700                 0.210533                 8.121033
# 8                  0.337600                 0.112533                 0.624533
# 9                  4.891600                 1.762433                 5.151100
# 10                 2.037100                10.366900                15.532933
# 11                 0.668633                 0.001633                 2.074033
# 12                 0.030100                 0.634800                 0.164100
# 13                 0.015633                 0.980233                 0.073433
# 14                 0.306533                 0.705233                 1.914033
# 15                 0.045000                 0.217800                 0.057800
